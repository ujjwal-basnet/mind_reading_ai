# %%
import dspy

# %%
import dspy
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()

# Your custom env var name
geminai_api_key= os.getenv("gemini")


geminai= os.getenv('gemini')
if geminai :

    lm = dspy.LM("gemini/gemini-2.5-flash", api_key=geminai_api_key)
    dspy.configure(lm=lm)
else :
    print("GEMINI API KEY NOT FOUND")
# Out:
# GEMINI API KEY NOT FOUND

# %%
class sentimentClassifier(dspy.Signature):
    """ Classify the sentiment of a text """
    text:str = dspy.InputField(desc= "input text to classfity sentiment")
    sentiment= dspy.OutputField(desc= "sentiment of the text" , ge=0 , le= 0 )

# %%
class SentimentClassifier(dspy.Signature):
    """Classify the sentiment of a text."""
    text: str = dspy.InputField(desc="input text to classify sentiment")
    sentiment: int = dspy.OutputField(desc="sentiment, the higher the more positive", ge=0, le=10)

cot = dspy.ChainOfThought(SentimentClassifier)
output = cot(text="I am feeling pretty happy!")
# Out:
# 2025/09/06 16:03:55 WARNING dspy.adapters.json_adapter: Failed to use structured output format, falling back to JSON mode.
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/codes/mind_reading_ai/.venv/lib/python3.11/site-packages/litellm/llms/vertex_ai/gemini/vertex_and_google_ai_studio_gemini.py:2017, in VertexLLM.completion(self, model, messages, model_response, print_verbose, custom_llm_provider, encoding, logging_obj, optional_params, acompletion, timeout, vertex_project, vertex_location, vertex_credentials, gemini_api_key, litellm_params, logger_fn, extra_headers, client, api_base)
#    2016 try:
# -> 2017     response = client.post(url=url, headers=headers, json=data)  # type: ignore
#    2018     response.raise_for_status()
#
# ...
